# %% [markdown]
# <a href="https://colab.research.google.com/github/ikyath/AI_Medical_Specialization/blob/master/pytorch_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
print(arr)

# %%
arr.dtype

# %%
type(arr)

# %%
torch.from_numpy(arr)

# %%
torch.as_tensor(arr).dtype

# %%
arr2d = np.arange(0.0,15.0)

# %%
x2 = torch.from_numpy(arr2d.reshape(5,3))
x2
